# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import pandas as pd
from pathlib import Path
#（sequence: CatBOX, CAS, COCABO, MVRSM, TPE, EDBO, GPyOpt, RS）

# %%
fp = f'optimization_results_update/benchmarks3+10+5/Ackley_benchmark/Ackley-r-benchmark_ei_4_path_analysis.pkl'
with open(fp, 'rb') as f:
    data = pickle.load(f)
data[7][1]
# Out:
# array([[-21.46845829],
#        [-20.94448909],
#        [-21.41282161],
#        [-21.24333444],
#        [-20.54518611],
#        [-20.66367396],
#        [-20.99676772],
#        [-20.76081105],
#        [-20.25705238],
#        [-21.25945257],
#        [-21.45535082],
#        [-21.53404515],
#        [-21.27904263],
#        [-21.39696675],
#        [-20.91152297],
#        [-21.43859173],
#        [-21.25547682],
#        [-21.49079633],
#        [-21.17949283],
#        [-21.50245418],
#        [-21.20738582],
#        [-20.01435274],
#        [-20.96881186],
#        [-21.19724474],
#        [-21.02620098],
#        [-21.50744245],
#        [-20.81791177],
#        [-21.42337268],
#        [-21.37720077],
#        [-21.01663701],
#        [-20.98340111],
#        [-20.6608114 ],
#        [-21.41502416],
#        [-21.56174771],
#        [-20.93419946],
#        [-21.18838181],
#        [-21.56582956],
#        [-20.94218867],
#        [-21.20107956],
#        [-20.8996534 ],
# ...
