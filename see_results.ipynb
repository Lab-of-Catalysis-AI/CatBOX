# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import pandas as pd
from pathlib import Path
#（sequence: CatBOX, CAS, COCABO, MVRSM, TPE, EDBO, GPyOpt, RS）

# %%
fp = f'optimization_results_update/SCR_sep/SCR-r-sep_ei_0_path_analysis.pkl'
with open(fp, 'rb') as f:
    data = pickle.load(f)
data[7][1]
# Out:
# array([[ 72.45068418],
#        [ 65.18061918],
#        [ 39.96796125],
#        [ 40.81717763],
#        [ 88.38899235],
#        [-10.8379195 ],
#        [ 81.75830116],
#        [ 74.58827261],
#        [ 76.32329625],
#        [ 57.09260578],
#        [ 17.77190808],
#        [ 35.04842449],
#        [ 62.97425158],
#        [ 58.67837609],
#        [ 48.61941606],
#        [ 81.11026768],
#        [ 63.60403454],
#        [ 39.42025069],
#        [ 12.59852433],
#        [ 39.10713221],
#        [ 79.8588418 ],
#        [-11.81795884],
#        [ -5.08831063],
#        [ 59.9789812 ],
#        [ 29.73106461],
#        [ 74.90689136],
#        [ 47.85645739],
#        [ 38.26406181],
#        [ 81.40872238],
#        [ 85.01351216],
#        [ 13.33375236],
#        [ 50.05048054],
#        [ 36.89454678],
#        [ 71.49272162],
#        [ 34.31491166],
#        [ 79.61257983],
#        [ 62.62511477],
#        [ 83.7383962 ],
#        [ 66.53855922],
#        [ 79.37881501],
# ...
